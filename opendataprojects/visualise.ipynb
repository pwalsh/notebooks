# %% [markdown]
# # Visualising data
#
# - We have data loaded into Python data structures
# - We have some basic insights into data
# - Wouldn't it be great to "see" it?

# %% [markdown]
# ## Tools
#
# - [Bokeh](http://bokeh.pydata.org/en/latest/) for interactive visualisations from Python
# - [Python's enumerate builtin](https://docs.python.org/3/library/functions.html#enumerate)
# - Data from [OpenSpending](http://next.openspending.org/explorer/)

# %% [markdown]
# ## Examples
#
# We'll walk through a very simple example, building on our previous step:
#
# - perform basic analysis on the data
# - create a data structure that is amenable to charting
# - build some visualisations for our data!

# %%
# just for presentation in notebooks
from pprint import pprint as print

# %%
import operator
import requests
import csv
import decimal
import re
from dateutil.parser import parse as dateparse
from bokeh.charts import Bar, show, output_notebook


output_notebook()

csv_source = 'https://s3.amazonaws.com/datastore.openspending.org/21260d070eb5d63a121ea4c400dafbbb/apbn_fungsi_2016/example_os.csv'

csv_delimiter = ';'

response = requests.get(csv_source)

raw = response.text.splitlines()

reader = csv.DictReader(raw, delimiter=csv_delimiter)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c83d69cc-708e-4f74-8fe8-8619eb372de1">Loading BokehJS ...</span>
#     </div>

# %%
def clean(row):
    """Clean rows of data."""
    for key, value in row.items():
        try:
            if key in ('Revised', 'Original'):
                value = re.sub('[,]', '', value)
                if value == '':
                    value = 0
                value = float(value)
            row[key] = value
        except Exception:
            pass

    return row

# %%
data = []

for row in reader:
    row = clean(row)
    data.append(row)

# %% [markdown]
# ## A sample

# %%
print(data[0])
# Out:
# {'Code': '01',
#  'Function': 'GENERAL PUBLIC SERVICE',
#  'Original': 3165326.0,
#  'Revised': 3225881.0,
#  'Year': '2016'}

# %%
chart = Bar(data, 'Function', values='Revised', title='Spending by function', legend=False)

show(chart)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="40b79274-5230-4a25-b2e4-041d5ba356df"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#40b79274-5230-4a25-b2e4-041d5ba356df").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("40b79274-5230-4a25-b2e4-041d5ba356df");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '40b79274-5230-4a25-b2e4-041d5ba356df' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f2b6a5ab-4175-469e-bbd6-75d4cf282955":{"roots":{"references":[{"attributes":{"data_source":{"id":"896a0f2a-7248-46e9-a661-bbebca65ea84","type":"ColumnDataSource"},"glyph":{"id":"e58eeea1-48d1-4996-9c8a-cf9f5601325a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e73ac9fd-f9c7-4321-a2b1-90d946557e6a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"af2b8a2b-1391-4fad-b6ce-06ca894d6cb4","type":"ColumnDataSource"},"glyph":{"id":"1498fe72-8925-473e-a4a1-6e2f606de05a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ff1b4345-2282-466b-8cc3-83a378ad1d6d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7771741d-1634-4a07-9c62-7248700e8bd2","type":"ColumnDataSource"},"glyph":{"id":"a3ed639f-4533-477d-ac59-36d942ceaccf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"69f9d6fc-7fa4-43a6-841b-ed0c7e5d0835","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["fill_alpha","line_alpha","x","color","line_color","y","label","width","height"],"data":{"Function":["TOURISM"],"chart_index":[{"Function":"TOURISM"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[58686.0],"label":[{"Function":"TOURISM"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["TOURISM"],"y":[29343.0]}},"id":"8617f4c3-66c2-4929-9fec-3bc5dc0afb06","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"320baf69-de1d-4c70-b2f6-64bb0250d3b0","type":"ColumnDataSource"},"glyph":{"id":"272b5449-f4b8-400b-8210-c913a93d26bd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"521a4a7c-6bae-4217-8b9f-819a4789632f","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5ae25405-49ef-49a9-87d8-b54743cca1f5","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"7ef9cfdd-ae30-4964-bb53-a6fa03916479","type":"ColumnDataSource"},"glyph":{"id":"8dec3140-d9fe-47d9-ac9e-329fb98e1162","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bcb8b014-613a-4356-8694-cc2336b1f7b1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["fill_alpha","line_alpha","x","color","line_color","y","label","width","height"],"data":{"Function":["HEALTH"],"chart_index":[{"Function":"HEALTH"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[660698.0],"label":[{"Function":"HEALTH"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["HEALTH"],"y":[330349.0]}},"id":"320baf69-de1d-4c70-b2f6-64bb0250d3b0","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"7e964c95-0111-4351-bb5c-7b17ad859692","type":"CategoricalAxis"}],"left":[{"id":"c0848547-6ec6-4675-8646-71342db1839a","type":"LinearAxis"}],"renderers":[{"id":"5ae25405-49ef-49a9-87d8-b54743cca1f5","type":"BoxAnnotation"},{"id":"ff1b4345-2282-466b-8cc3-83a378ad1d6d","type":"GlyphRenderer"},{"id":"237dec40-afa6-461e-a453-5e020564a2b1","type":"GlyphRenderer"},{"id":"19c2bac8-ff71-4d16-88a6-b34a721429d2","type":"GlyphRenderer"},{"id":"e73ac9fd-f9c7-4321-a2b1-90d946557e6a","type":"GlyphRenderer"},{"id":"4a0a48f8-3acf-4664-84fa-976b8b6bcfdf","type":"GlyphRenderer"},{"id":"69f9d6fc-7fa4-43a6-841b-ed0c7e5d0835","type":"GlyphRenderer"},{"id":"521a4a7c-6bae-4217-8b9f-819a4789632f","type":"GlyphRenderer"},{"id":"3f74bfa1-f6b3-4c82-99e0-ce6b56792337","type":"GlyphRenderer"},{"id":"1ac94368-195a-4832-a8ec-f0d78198cd9d","type":"GlyphRenderer"},{"id":"bcb8b014-613a-4356-8694-cc2336b1f7b1","type":"GlyphRenderer"},{"id":"2ab055b0-cb2e-4fd9-b1e8-1b1481aed059","type":"GlyphRenderer"},{"id":"7e964c95-0111-4351-bb5c-7b17ad859692","type":"CategoricalAxis"},{"id":"c084854 ...

# %% [markdown]
# ## What else?
#
# - Display of amounts on the chart
# - Stack different measures
# - If the data has a date column, show spend over time
# - Explore the [Bokeh Charts documentation](http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html)
